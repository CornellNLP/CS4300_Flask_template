# %%
from collections import defaultdict
from collections import Counter
import json
import math
import string
import time
import numpy as np
from nltk.tokenize import TreebankWordTokenizer
from IPython.core.display import HTML
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import PorterStemmer
import re

# %%
with open("finalData.json", "r") as f:
    data = json.load(f)

# %%
small_data = data['BOSTON']

# %%
index_to_restaurant = {i: v for i, v in enumerate(small_data.keys())}

# %%
index_to_restaurant
# Out:
# {0: 'Longwood Galleria',
#  1: 'Legal Sea Foods',
#  2: 'Espresso Minute',
#  3: 'Amrheins',
#  4: "Fiouna's Persian Fusion Cuisine",
#  5: 'Code 10',
#  6: 'Star Market',
#  7: 'Shenannigans Bar',
#  8: "McGann's Pub",
#  9: "Whiskey's Food & Spirits",
#  10: 'Burger King',
#  11: "Fin's Sushi & Grill",
#  12: 'Campo di Fiori',
#  13: 'The North End',
#  14: 'Blue Wave',
#  15: "Herrera's",
#  16: 'Aragosta Bar and Bistro',
#  17: 'Pressed Sandwiches',
#  18: 'Fin Point Oyster Bar + Grille',
#  19: 'Sister Sorel',
#  20: 'Cha Cha Cha Taqueria',
#  21: 'The Boston Chipyard',
#  22: 'Restaurante Cesaria',
#  23: 'Flemings Prime Steakhouse & Wine Bar',
#  24: 'Boloco',
#  25: 'Croma',
#  26: 'Sidebar Boston',
#  27: 'Five Horses Tavern',
#  28: 'Beantown Pho & Grill',
#  29: 'Al Capone Pizza Pasta & Meats',
#  30: 'Scoozi Newbury',
#  31: 'Charles River Bistro',
#  32: "Roxy's Gourmet Grilled Cheese",
#  33: 'Oppa Sushi',
#  34: "Broad Street Paulie's",
#  35: "Lilly's Gourmet Pasta Express",
#  36: "Amelia's Taqueria",
#  37: "Emilio's",
#  38: 'Empire Asian Restaurant & Lounge',
#  39: "Floramo's Deli",
#  40: "Joe Tecce's Ristorante & Caffe",
#  41: 'Il Mondo II',
#  42: 'Zo Greek',
#  43: 'Breadwinners',
#  44: 'Giddy Up',
#  45: 'Assaggio',
#  46: 'Tawakal Halal Cafe',
#  47: 'El Jardin',
#  48: 'Style Cafe',
#  49: 'Boloco Northeastern',
#  50: 'Sushi Factory',
#  51: 'Boston Kitchen Pizza',
#  52: "Molly's Farmhouse Coffee",
#  53: 'Brew',
#  54: "Daisy Buchanan's",
#  55: 'Pavia Italian Cuisine Catering & More',
#  56: 'Boston Kebab House',
#  57: 'PJP Cleaning Services',
#  58: 'U Food Grill',
#  59: 'Boba Me',
#  60: 'Vaisakhi Indian Kitchen',
#  61: 'Cultivar',
#  62: "Gene's Chinese Flatbread Cafe",
#  63: 'Koy',
#  64: 'Prudential Center',
#  65: "Parziale's Bakery",
#  66: 'InBoston',
#  67: 'Uno Pizzeria & Grill',
#  68: 'The Fish Shack',
#  69: 'Caffè Nero',
#  70: 'Kitchen',
#  71: "Hennessy's",
#  72: 'Greek Isles',
#  73: 'Taj Boston',
#  74: 'Pearl Villa Seafood Restaurant',
#  75: 'Napoles Restaurant',
#  76: 'Meritage Restaurant',
#  77: "Maggiano's Little Italy",
#  78: "Sissy K's",
#  79: 'Game On',
#  80: 'Odyssey Cruises Boston',
#  81: 'Shake Shack',
#  82: 'Newbury Street',
#  83: 'Mandarin Oriental Hotel',
#  84: 'Subway',
#  85: "Paddy O's",
#  86: 'Thaitation',
#  87: 'Metropolis',
#  88: 'Grotto',
#  89: 'Pret A Manger',
#  90: "Harry O's Pizza",
#  91: 'Locale',
#  92: "Nunzio's Pizzeria",
#  93: 'Stephanie’s',
#  94: 'Friendship BBQ',
#  95: "Boston's Big Easy",
#  96: "Mike's Banh Mi",
#  97: 'Mohr & McPherson Café',
#  98: "McDonald's",
#  99: 'Arbri Cafe',
#  100: "Santarpio's Pizza",
#  101: 'Salty’s',
#  102: "Jane's Salad & Buffet",
#  103: 'Reef Bar',
#  104: 'Cosi Sandwich Bar',
#  105: 'Miel Brasserie',
#  106: "Dillon's",
#  107: 'Milkweed',
#  108: 'Felt',
#  109: 'Cottonwood Cafe',
#  110: 'Jyuba',
#  111: 'Tuscan Kitchen - Seaport',
#  112: 'TR Street Foods',
#  113: 'La Chiva Restaurant',
#  114: 'Buco Trattoria',
#  115: 'Mighty Love Food',
#  116: "My Cousin's Place",
#  117: 'New American Cafe',
#  118: 'Sushi Time',
#  119: 'Life Alive Organic Cafe',
#  120: 'Bacco',
#  121: 'House of Blues Boston- Music Venue',
#  122: '300 Saratoga Cafe',
#  123: 'The Florentine Cafe',
#  124: 'Barcelona Wine Bar South End',
#  125: 'West End Johnnies',
#  126: 'Sbarro',
#  127: 'The Gallery',
#  128: "Monica's Trattoria",
#  129: 'Krispy Kreme',
#  130: 'The Avenue',
#  131: 'Cafe 57 & Grill',
#  132: "Buddha's Delight",
#  133: 'PURR Cat Cafe',
#  134: 'Doughboy Donuts & Deli',
#  135: 'Thai Dish',
#  136: 'Ginger Exchange Symphony',
#  137: 'Spangler Food Court at Harvard Business School',
#  138: "Maria's Taqueria",
#  139: 'Ma Soba',
#  140: 'Amici Italian Cuisine',
#  141: 'Shin Hakata Ramen',
#  142: 'Budweiser Legends Club',
#  143: '163 Vietnamese Sandwiches & Bubble Tea',
#  144: "Rebecca's Cafe and Catering",
#  145: 'The Gallows',
#  146: "Jennifer Lee's Gourmet Bakery",
#  147: 'Casalinga',
#  148: "Frank Anthony's Gourmet Market",
#  149: "Johnny's Pockets",
#  150: 'Panera Bread',
#  151: 'The King Restaurant',
#  152: 'Pho Hoa Noodle Soup',
#  153: 'The Halal Guys',
#  154: 'Vino Volo',
#  155: 'Staff Meal',
#  156: "Aesop's Bagels",
#  157: "Dunkin' Donuts",
#  158: 'Parish Cafe and Bar',
#  159: 'Cheeseboy',
#  160: 'La Sultana Bakery',
#  161: "Sophia's Cafe",
#  162: 'Greenlight Cafe',
#  163: 'Pepper Pot',
#  164: '33 Restaurant & Lounge',
#  165: "Wing's Kitchen",
#  166: 'Tsaocaa',
#  167: 'New York Pizza',
#  168: "Muscarella's Market",
#  169: 'Pizza Oggi',
#  170: 'Que Padre',
#  171: 'Shredded',
#  172: 'Azure',
#  173: 'The Point',
#  174: 'Tavern In The Square',
#  175: 'Champions',
#  176: "Rudi's Resto Café & Bar",
#  177: 'Brother Trucker - Go Fish!',
#  178: 'Parish Cafe',
#  179: 'Charles Street Market',
#  180: 'Boston Super Dog',
#  181: 'Lucky Strike Boston',
#  182: 'PABU Izakaya Boston',
#  183: 'New Shanghai',
#  184: 'Red Moon',
#  185: 'Symphony 8',
#  186: 'Cafe Golden Horn',
#  187: 'M C Spiedo',
#  188: 'Rail Stop Restaurant & Bar',
#  189: 'Mala Restaurant',
#  190: "Pho's Asian",
#  191: 'Kaya Restaurant',
#  192: 'Café Quattro',
#  193: 'Z Square',
#  194: "Bertucci's",
#  195: 'Haru Sushi - Boston',
#  196: 'Tico Boston',
#  197: 'Ice Age',
#  198: "Joe's Famous Steak & Cheese",
#  199: 'Alma Gaucha',
#  200: "DJ's at The Garden",
#  201: 'Papagayo',
#  202: 'Au Bon Pain',
#  203: 'Cafe 26',
#  204: 'Boston Chowda Co',
#  205: 'Back Bay Sandwich',
#  206: 'Dumpling Palace',
#  207: 'Tremont House Of Pizza',
#  208: "Rhythm 'n Wraps Truck",
#  209: 'Render Coffee',
#  210: 'Souper Salad',
#  211: 'Clover Food Lab',
#  212: 'Pier Fish Co',
#  213: "T's Pub",
#  214: "Steve's Greek Cuisine",
#  215: 'MOOYAH Burgers, Fries & Shakes',
#  216: 'QDOBA Mexican Eats',
#  217: 'The Hub Pub',
#  218: 'Eat Street Cafe',
#  219: 'Cactus Club',
#  220: "Mr. Dooley's",
#  221: 'Saus',
#  222: 'UBurger',
#  223: 'Pho 1 Brighton',
#  224: "Loconte's Italian Cuisine",
#  225: 'J. Pace & Sons',
#  226: 'Popover King',
#  227: 'Jen Lai Noodle & Rice Company',
#  228: "Quincy's Place",
#  229: 'Zen Japanese Grill & Sushi Bar',
#  230: 'Mana Escondido Café',
#  231: "Cardullo's Gourmet Shoppe",
#  232: 'Mangia Neapolitan Pizzeria',
#  233: 'Zuma',
#  234: 'Circle',
#  235: 'Bonfire',
#  236: "Hurricane's at the Garden",
#  237: "Wong's of Boston",
#  238: 'Canton Eatery',
#  239: "Rebecca's Cafe",
#  240: 'The Sausage Guy',
#  241: 'Myers & Chang',
#  242: 'McFly’s',
#  243: 'Lower Mills Tavern',
#  244: 'Hot Pot Buffet',
#  245: "Marva's Place",
#  246: 'Locke-Ober',
#  247: 'Society On High',
#  248: 'Boston Pocket & Deli',
#  249: 'Barking Crab',
#  250: 'Caffe Lil Italy',
#  251: "Domino's Pizza",
#  252: 'Clay Pot Cafe',
#  253: 'GreCo',
#  254: 'Stella',
#  255: 'B&G Oysters',
#  256: 'Trio Cafe Boston',
#  257: 'Noche',
#  258: 'Linwood Grill & BBQ Restaurant',
#  259: 'South Ocean',
#  260: 'Starbucks',
#  261: "Jose McIntyre's",
#  262: 'Prezza',
#  263: 'Max & Dylans',
#  264: 'Caffe Pompei',
#  265: 'Pasteur',
#  266: 'Shino Express Sushi',
#  267: "Murl's Kitchen",
#  268: 'Kaze Shabu Shabu',
#  269: 'Ames Plow Tavern',
#  270: 'Mother Juice',
#  271: 'Jack and the Bean Bowl',
#  272: 'Blaze Pizza',
#  273: 'Sorelle',
#  274: 'Our House East',
#  275: 'Dawat Fine Indian Cuisine',
#  276: 'sweetgreen',
#  277: 'Barracuda On The Fly',
#  278: 'Paris Creperie Seaport',
#  279: 'Tiger Lily',
#  280: 'Rowes Wharf Sea Grille',
#  281: 'Cappy’s Pizza & Subs',
#  282: 'Black Seed Cafe & Grill',
#  283: 'The Sevens Ale House',
#  284: 'Select Oyster Bar',
#  285: 'Precinct Kitchen + Bar',
#  286: 'Ankara Cafe',
#  287: 'Stir',
#  288: "Theo's Cozy Corner",
#  289: 'Amsterdam Falafelshop',
#  290: 'St King Tavern',
#  291: "Xi'An Street Foods",
#  292: 'Tatte Bakery',
#  293: 'Hong Kong At Faneuil Hall',
#  294: 'La Baguette Marche',
#  295: 'A1 Grill & Pizza',
#  296: 'Rigoletto Ristorante',
#  297: 'Mariel',
#  298: 'Grand Tour',
#  299: 'B.Good Burgers - Take Out Only',
#  300: 'Caffe Nuovo',
#  301: "anoush'ella",
#  302: 'honeygrow',
#  303: 'Van Shabu & Bar',
#  304: 'Canestaro Restaurant & Pizzeria',
#  305: "Jerry Remy's Sports Bar & Grill",
#  306: 'Mass College of Art - The Dining Commons',
#  307: "Gennaro's 5 North Square",
#  308: "Andre's Cafe",
#  309: 'Sweet Cheeks Q',
#  310: "Coogan's",
#  311: 'Mumbai Spice',
#  312: 'Num Pang Kitchen',
#  313: 'Toscano Restaurant',
#  314: "Wendy's",
#  315: 'The Dish',
#  316: 'Montecristo Mexican Grill',
#  317: 'Decca',
#  318: 'The Grand Canal',
#  319: 'Rice Bowl',
#  320: 'Mama Blanca Restaurant',
#  321: 'Café de Lulu',
#  322: 'Pizzeria Rico',
#  323: 'Stats Bar & Grille',
#  324: 'Chinatown Cafe',
#  325: 'Firehouse Subs',
#  326: 'My Big Fat Greek Pizza',
#  327: 'Market',
#  328: 'Battery Park Bar & Patio',
#  329: 'wagamama - seaport',
#  330: 'The Wine Cellar',
#  331: "Mike's City Diner",
#  332: "Quan's Kitchen Chinese Food",
#  333: 'Restaurante Montecristo',
#  334: 'Kings Dining & Entertainment - Boston Seaport',
#  335: 'Wahlburgers',
#  336: 'La Cancun',
#  337: 'Mr. Kushari egyptian',
#  338: 'UFood Grill',
#  339: 'Bagels Etc',
#  340: 'The Daily Catch',
#  341: "McCormick & Schmick's Seafood & Steaks",
#  342: 'Newsfeed Cafe',
#  343: 'Tasty Burger',
#  344: "Salsa's Mexican Grill",
#  345: '75 Chestnut',
#  346: 'Regina Pizzeria',
#  347: 'Shaking Crab - Boston Common',
#  348: 'Thinking Cup',
#  349: 'Gourmet Eatery',
#  350: 'Finagle A Bagel',
#  351: 'The Creperie On Newbury',
#  352: 'Legal Crossing',
#  353: "Brigham & Women's Hospital - Cafeteria",
#  354: 'Dirty Water Dough',
#  355: 'by CHLOE. Boston Seaport',
#  356: 'M&J Teriyaki',
#  357: 'The Bar Room',
#  358: 'Boston Deli Deluxe',
#  359: 'City Landing',
#  360: 'Snappy Sushi',
#  361: 'Pan Roma Pizzeria & Grill',
#  362: 'JJ Foleys Cafe',
#  363: 'Milk Street Cafe',
#  364: 'Chipotle Mexican Grill',
#  365: 'Baco Banh Mi',
#  366: 'Fresh Food Generation',
#  367: 'Fuyami',
#  368: 'Lobby Bar & Kitchen',
#  369: 'Qdoba Mexican Grill',
#  370: "Ned Devine's Pub",
#  371: 'My Thai Vegan Cafe',
#  372: 'Oriental House Restaurant',
#  373: 'An Tain',
#  374: 'Nico Ristorante',
#  375: 'South Boston Chinese Restaurant',
#  376: 'Silvertone',
#  377: 'The Shannon Tavern',
#  378: 'Pressed Juicery',
#  379: 'ilona',
#  380: 'Falafel & Couscous',
#  381: 'Nourish Your Soul',
#  382: 'Viga Italian Eatery & Caterer',
#  383: 'GEM',
#  384: 'The Tap',
#  385: 'The Paramount',
#  386: 'District Pizzeria',
#  387: 'Rod Thai Family Taste',
#  388: 'West End Strollers',
#  389: 'Sorelle Bakery & Cafe',
#  390: 'Noon Mediterranean',
#  391: 'JA Stats Restaurant & Bar',
#  392: 'BURGERFI',
#  393: '209 Boston',
#  394: 'Tora Japanese Restaurant',
#  395: 'Pastoral - Artisan Pizza, Kitchen & Bar',
#  396: 'B.GOOD',
#  397: 'Ajeen',
#  398: 'Five-10 Waterfront',
#  399: 'Vinh-Sun',
#  400: 'Caffe Paradiso',
#  401: 'El Rancho Restaurante',
#  402: 'Earl of Sandwich',
#  403: "Kennedy's Midtown",
#  404: 'Xi’An Rougamo',
#  405: 'Mare',
#  406: 'JP Roti Shop',
#  407: 'Espresso Royale Caffe',
#  408: 'Berkshires',
#  409: 'District',
#  410: 'Sweet Rice JP',
#  411: 'Fresh City',
#  412: 'French Quarter',
#  413: 'Bao Bao Bakery & Cafe',
#  414: 'RYO Asian Fusion',
#  415: 'Scullers Jazz Club',
#  416: '75 On Courthouse Square',
#  417: 'Stella Cafe',
#  418: 'South End Open Market',
#  419: "O'Naturals",
#  420: 'Third Cliff Bakery',
#  421: 'Pho Basil',
#  422: 'Citizen Public House & Oyster Bar',
#  423: "Minina's Cafe",
#  424: 'Bistro du Midi',
#  425: 'Dig',
#  426: 'Saloniki Greek',
#  427: 'Right Taste Jamaican Restaurant',
#  428: 'Crepe & Ice Cream 89C',
#  429: 'Teavana',
#  430: "Georgianna's Market",
#  431: 'El Molino',
#  432: 'The White Bull Tavern',
#  433: 'Hot Tomatoes',
#  434: 'Chilacates Mexican Street Food',
#  435: 'Omni Parker House',
#  436: 'Shanghai Restaurant & Bar',
#  437: "Jimmy John's",
#  438: 'Nahita Cocktails and Cuisine',
#  439: "Benevento's",
#  440: 'Beantown Burrito',
#  441: "Nicole's Pizza",
#  442: 'Cambridge, 1.',
#  443: 'Curry House',
#  444: "Cask'n Flagon",
#  445: 'The Cheesecake Factory',
#  446: "Angela's Cafe - Eagle Hill",
#  447: "Foodie's Urban Market",
#  448: 'Misono Wok',
#  449: 'Burtons Grill',
#  450: 'Stadium Sports Bar & Grill',
#  451: "D'Angelo's Sandwich Shops",
#  452: 'CAVA',
#  453: 'Cosi',
#  454: 'Sorriso Trattoria',
#  455: 'Aqua Pazza',
#  456: 'Wisteria Restaurant',
#  457: 'RumBa',
#  458: 'MIDA',
#  459: 'LongHorn Steakhouse',
#  460: 'Potato Freaks',
#  461: 'Crepe and More',
#  462: 'Temptations Cafe',
#  463: "Boar's Nest Deli",
#  464: 'China Station',
#  465: 'Cini’s',
#  466: 'Chinatown Eatery',
#  467: 'Philadelphia Steak & Hoagie',
#  468: 'Dot Cafe',
#  469: 'Emerald Lounge',
#  470: 'Davide Restaurant',
#  471: 'Courtyard Tea Room',
#  472: 'Totto Ramen',
#  473: 'Hungry Traveler',
#  474: "Blake's",
#  475: 'Ledge Kitchen and Drinks',
#  476: 'Comedy Connection',
#  477: 'Café Jaffa',
#  478: 'Boston Common Coffee Co.',
#  479: "T Anthony's Restaurant",
#  480: 'Finagle-A-Bagel',
#  481: 'Tossed',
#  482: 'Bon Me',
#  483: "Stephanie's On Newbury",
#  484: 'Les Zygomates',
#  485: "Bogie's Place",
#  486: "Thornton's Fenway Grille",
#  487: 'DW Brewpub',
#  488: 'Pomodoro',
#  489: 'Cafe Vanille',
#  490: 'Bar Moxy',
#  491: 'Tonic',
#  492: "Vivian's Cafe",
#  493: 'Billy Tse Restaurant',
#  494: "Betty's Wok & Noodle Diner",
#  495: 'Wings Over Boston',
#  496: 'Boston Shawarma Restaurant',
#  497: 'Tavern Road',
#  498: 'Seapoint Restaurant',
#  499: 'Energize',
#  500: 'Iron Wok',
#  501: 'Chic Chick',
#  502: "Eddie V's Prime Seafood",
#  503: 'Sakura-Bana',
#  504: 'Avana Sushi',
#  505: 'Panificio',
#  506: 'Forty Dalton',
#  507: 'Caprice',
#  508: 'Boston Brewin Coffee',
#  509: "Sal's Pizza",
#  510: 'Dine Boston',
#  511: 'The Bowery Bar',
#  512: 'Purple Shamrock',
#  513: 'Eataly Boston',
#  514: 'Falafel King',
#  515: 'Grilled Cheese Nation',
#  516: 'Lolita Cocina & Tequila Bar Back Bay',
#  517: 'Venezia Restaurant Boston',
#  518: 'No Relation',
#  519: 'Island Creek Oyster Bar',
#  520: 'Double Chin',
#  521: "Victoria's Diner",
#  522: 'East Ocean City',
#  523: 'Dosa Factory - Boston',
#  524: 'Fuji at Ink Block',
#  525: 'Upper Crust Pizzeria',
#  526: 'DoubleTree Suites by Hilton Hotel Boston - Cambridge',
#  527: 'Mission Sushi & Wok',
#  528: 'Boston Pizza and Grill',
#  529: 'Dates & Olives',
#  530: 'Unchained Pizza',
#  531: 'Three Cheers Restaurant Bar & Function Facility',
#  532: 'College Pizza',
#  533: 'Market Kitchen',
#  534: 'Deuxave',
#  535: "Mul's Diner",
#  536: 'Munch Mobile Kitchen',
#  537: 'Aceituna Grill',
#  538: "Morton's The Steakhouse",
#  539: 'Rock Bottom Restaurant & Brewery',
#  540: "Finn McCool's Boston",
#  541: "Sam LaGrassa's",
#  542: "Broadway's Best Pizza",
#  543: 'Peruvian Taste',
#  544: 'Alexandria Pizza & Grill',
#  545: 'Best Sausage',
#  546: "Stephi's in Southie",
#  547: 'Berkshire Farms Market',
#  548: 'Wink & Nod',
#  549: 'Cafe G',
#  550: 'Burrito Max',
#  551: 'Three Clover Pizza Restaurant',
#  552: 'Smith & Wollensky',
#  553: 'Mei Mei Restaurant',
#  554: 'Saltie Girl',
#  555: 'Evergreen Eatery',
#  556: 'Brasserie Jo',
#  557: 'Strip By Strega',
#  558: 'Minibar',
#  559: 'Panza',
#  560: 'Pierrot Bistrot Francais',
#  561: 'Marco',
#  562: "Riccardo's Ristorante",
#  563: 'Pazzo Ristorante & Bar',
#  564: 'Caprice International Burger Bar',
#  565: "The Four's Restaurant & Sports Bar",
#  566: 'New Saigon',
#  567: 'Park Square Cafe',
#  568: 'Kaju Tofu House',
#  569: 'The Hill Tavern',
#  570: 'Bonchon Allston',
#  571: 'Blackmoor Bar and Kitchen',
#  572: 'SOJUba',
#  573: 'Quotes Cafe',
#  574: "Bruegger's Bagels",
#  575: "Papi's Stuffed Sopapillas",
#  576: 'Yellowbird Chicken',
#  577: 'Artu',
#  578: 'Ward 8',
#  579: 'The Maiden',
#  580: 'Tawakal Halal Cuisine',
#  581: 'Uptown Espresso Caffe',
#  582: 'Franklin Southie',
#  583: "May's Cake House",
#  584: "Dunkin'",
#  585: 'Boston Crust',
#  586: 'Jalapenos',
#  587: 'Currito',
#  588: "Poe's Kitchen At the Rattlesnake",
#  589: 'Casa Razdora',
#  590: "Happy's Bar & Kitchen",
#  591: 'Phillips Old Colony House',
#  592: 'City Tap House',
#  593: 'Five Star Pizza Grill',
#  594: 'Cafe Latino',
#  595: "Contrada's Coffee",
#  596: "Dick's Last Resort",
#  597: 'Bangkok City',
#  598: "Vinny T's of Boston",
#  599: 'India Quality Restaurant',
#  600: 'Aris BBQ',
#  601: 'Kantin',
#  602: 'Tapestry',
#  603: 'Committee',
#  604: "Thornton's",
#  605: 'Bar Lyon',
#  606: 'Caribbean Flavors',
#  607: 'PadThai Cafe',
#  608: 'The Squealing Pig',
#  609: 'Lala  Restaurant',
#  610: 'Sushiemon',
#  611: 'University Grill & Pizza',
#  612: 'Beantown Pastrami',
#  613: 'Indulge India Food truck',
#  614: 'The Chicken Bone',
#  615: 'The Five Seventy Market',
#  616: 'Uburger',
#  617: 'Squeeze Juice',
#  618: 'Scissors and Pie',
#  619: 'ReelHouse Boston',
#  620: 'Tikkaway Fresh Indian Grill',
#  621: 'Riverview Cafe',
#  622: 'Ali Baba',
#  623: "Sandella's Flatbread Cafe",
#  624: 'Boston Chops South End',
#  625: 'Vineyard Grille',
#  626: 'Basile - Fine Italian Kitchen',
#  627: 'Good Life',
#  628: 'Bon Me - Back Bay',
#  629: 'Masa',
#  630: 'Snap Top Market',
#  631: 'Scholars American Bistro and Cocktail Lounge',
#  632: "Cappy's II",
#  633: 'Sub City',
#  634: 'Pasta E Pomodoro',
#  635: 'Legal Harborside',
#  636: 'Burritos and Tacos To Go',
#  637: 'Whiskey Park',
#  638: 'Seoul - Boston',
#  639: 'Royal Rooters Club',
#  640: 'Vaanga',
#  641: "Charley's Eating & Drinking Saloon",
#  642: "Luna's Restaurant Italian and Latin Cuisine",
#  643: 'The Monkey Bar',
#  644: "Rhett's",
#  645: 'La Galleria 33',
#  646: 'Causeway Restaurant & Bar',
#  647: "Rachel's Kitchen",
#  648: 'Seoul Soulongtang',
#  649: 'Church',
#  650: 'Samurai Kuang Eatery',
#  651: "Gourmeli's",
#  652: 'Pho Common',
#  653: 'Little Dipper',
#  654: 'Rowes Wharf Bar - Boston Harbor Hotel',
#  655: 'Piccolo Panini',
#  656: 'New Saigon Sandwich',
#  657: 'Prairie Star',
#  658: 'Which Wich',
#  659: 'Jer-ne Restaurant and Bar',
#  660: 'Restaurant L',
#  661: 'La Rana Rossa',
#  662: "Sam's",
#  663: 'Italian Express Pizzeria',
#  664: 'Typhoon Asian Bistro',
#  665: 'Greek Village Gyros & Grill',
#  666: 'Red Line Pizza & Grill',
#  667: "McGoo's Pizza",
#  668: 'Le Patissier at Troquet',
#  669: 'Solid Ground Cafe',
#  670: '21st Amendment',
#  671: 'Juice Press',
#  672: 'Union Park Pizza',
#  673: "Del Frisco's Double Eagle Steakhouse",
#  674: "Dog 'n Claw",
#  675: 'Pressed',
#  676: "Mario's Restaurant",
#  677: 'Serafina Downtown',
#  678: 'Tatte Bakery & Cafe',
#  679: "Maxine's On Saint James",
#  680: 'Xinh Xinh',
#  681: 'Cuffs',
#  682: "Kitty O'Shea's",
#  683: 'OTTO',
#  684: 'Bricco',
#  685: 'The Mission Bar & Grill',
#  686: 'Grainmaker',
#  687: 'Madina Market',
#  688: 'Aquitaine',
#  689: 'Orá Trattorizza',
#  690: 'Sapóre Ristorante & Bar',
#  691: 'Samurai Boston',
#  692: 'Limoo Tea Bar',
#  693: 'La Parrilla',
#  694: 'ZC Boston',
#  695: 'No. 9 Park',
#  696: 'Jaho Coffee & Tea',
#  697: 'Sleeper Street Cafe',
#  698: 'Gogi On The Block',
#  699: 'Sarku Japan',
#  700: 'Chart House',
#  701: 'The Cafe Royale',
#  702: 'Windmill Food Factory',
#  703: 'Andrew Square House of Pizza',
#  704: 'Teatro',
#  705: 'Casa Caña',
#  706: 'Home.Stead Bakery & Cafe',
#  707: 'Bourbon Street Cafe',
#  708: 'Roost Bistro',
#  709: "Barney Fanning's",
#  710: 'Worden Hall',
#  711: 'UMass Club',
#  712: 'Chinese Mirch',
#  713: 'Brown Sugar Cafe',
#  714: 'Kingfish Hall',
#  715: 'Mei Mei Street Kitchen',
#  716: 'The Wrap',
#  717: 'Golden Star Chinese Restaurant',
#  718: 'Union Club',
#  719: 'Sixth Gear - Cask & Kitchen',
#  720: 'Saté Grill-on-Wheels',
#  721: 'Squeeze Juice Company',
#  722: 'Carmen Trattoria',
#  723: "Anna's Taqueria",
#  724: 'Hopewell Bar & Kitchen',
#  725: 'Tiger Mama',
#  726: 'Berkeley Cafe',
#  727: 'Salty Dog Seafood Grille & Bar',
#  728: 'Bukowski Tavern',
#  729: 'GoGo Stop',
#  730: 'Hei La Moon',
#  731: 'Moonshine 152',
#  732: 'Fratellos Pizzeria and Shawarma',
#  733: 'Sprout',
#  734: 'P&R Restaurant And Ice Cream Parlor',
#  735: "Evan's NY Deli",
#  736: 'Cold Stone Creamery',
#  737: 'Bocao Restaurant &Grill',
#  738: 'Towne Stove and Spirits',
#  739: 'Know Fat Lifestyle Grille',
#  740: 'Sakura',
#  741: 'Addis Red Sea',
#  742: 'Servia',
#  743: "Luigi and Roscoe's",
#  744: 'Chau Chow City',
#  745: 'Food Court At the Prudential Center',
#  746: 'Boston Common Lemonade Cart',
#  747: 'Baltic Deli & Cafe',
#  748: 'Red Sky',
#  749: 'Redbones Food Truck',
#  750: 'Tertulias',
#  751: 'Temazcal Tequila Cantina',
#  752: 'Olympic House of Pizza',
#  753: 'Honeycomb Cafe',
#  754: 'Julep Bar',
#  755: 'Crossroads Irish Pub',
#  756: 'Hadja African Hair Braiding',
#  757: 'Laz All Day Breakfast and Pizzeria',
#  758: "Crazy Dough's Pizza",
#  759: "Milano's Delicatessen",
#  760: "Bakey's Restaurant",
#  761: 'Pupuseria Mama Blanca',
#  762: 'Slide By Food Truck',
#  763: 'Bostone Pizza',
#  764: 'No Name Restaurant',
#  765: 'Mentei',
#  766: 'Asian Too Express',
#  767: 'Umi Japanese Cuisine and Sushi Bar',
#  768: 'Babbo Pizzeria e Enoteca',
#  769: 'The Lenox Hotel',
#  770: 'Banh Mi Oi',
#  771: 'T Sushi Wraps & Noodles',
#  772: 'La Verdad',
#  773: 'Boston Pizza Express',
#  774: 'Kayuga',
#  775: 'Cornish Pasty',
#  776: 'Boston Shawarma',
#  777: 'Times Irish Pub & Restaurant',
#  778: 'Earls Kitchen + Bar',
#  779: "Mrs. B's Cafe",
#  780: 'Solas Irish Pub',
#  781: 'Yum Yum Noodle',
#  782: 'BiBim Box',
#  783: "Lucky's Lounge",
#  784: 'John Hancock Building Concourse Cafe',
#  785: 'Flour Bakery & Cafe',
#  786: '6B Lounge',
#  787: 'Villa Mexico',
#  788: 'Flat Iron Tapas Bar',
#  789: "Truly Jorg's Patisserie",
#  790: "D'Parma Restaurant",
#  791: 'Casarecce',
#  792: "Davio's",
#  793: 'Cisco Brew Pub',
#  794: "Tia's Waterfront",
#  795: 'wagamama - prudential',
#  796: 'Nusr-et Steakhouse',
#  797: 'The Farmacy Cafe',
#  798: 'Buttermilk & Bourbon',
#  799: 'Sam Adams Brewhouse',
#  800: 'The Elephant Walk',
#  801: 'Sonsie',
#  802: 'Liberty Bell Roast Beef',
#  803: 'Cinquecento',
#  804: 'La Catrina',
#  805: 'The Cornerstone Restaurant & Pub',
#  806: 'Legal C Bar',
#  807: 'by CHLOE. - Back Bay',
#  808: "Skipjack's Seafood Emporium",
#  809: 'Causeway Cafe',
#  810: 'Halftime Pizza',
#  811: 'Buskers Burger Bar',
#  812: "Sultan's Kitchen",
#  813: 'Taza Chocolate Bar',
#  814: "Busker's Lounge",
#  815: 'Aristo Cafe',
#  816: "Harry's Cheese and Cold Cuts",
#  817: 'Laughing Monk Cafe',
#  818: 'Marche Restaurant',
#  819: 'Regal Cafe',
#  820: 'The Chicken & Rice Guys - Downtown',
#  821: 'Barracuda Tavern',
#  822: 'Lola 42',
#  823: 'China Garden',
#  824: 'The Atrium Cafe',
#  825: 'Fill-A-Buster',
#  826: 'Townsman',
#  827: 'Union Oyster House',
#  828: 'Panda Express',
#  829: 'Mister Q Cafe',
#  830: 'Sushi Arigato',
#  831: "Gail's Cafe and Grill",
#  832: 'Ozone',
#  833: 'Paris Creperie',
#  834: 'Lucca Restaurant & Bar',
#  835: 'Thai Basil Restaurant',
#  836: 'Boloco Copley Square',
#  837: 'Fenmore Grill',
#  838: 'The Harp',
#  839: "L'Osteria",
#  840: "Figaro's",
#  841: "Tony C's Sports Bar & Grill",
#  842: '1000 Degrees Neapolitan Pizzeria',
#  843: 'Bottega Fiorentina',
#  844: 'VERTS Mediterranean Grill',
#  845: 'The Pour House',
#  846: 'Trattoria Andiamo',
#  847: '68 Chinese',
#  848: 'Little Haiti Cuisine',
#  849: 'Café 47',
#  850: 'Deja Brew',
#  851: 'Pizza Stop',
#  852: 'J Pace & Son',
#  853: 'Crispy Crêpes Cafe',
#  854: "Sheline's Snack Bazaar",
#  855: "Giorgiana's",
#  856: 'Piadina Cafe & Coffee Bar',
#  857: 'Eire Pub',
#  858: 'Maluken Japanese Restaurant',
#  859: 'Blackjack Pasta Kitchen',
#  860: 'Fish Pier Restaurant & Market',
#  861: 'Boston Burger - Boston',
#  862: 'Shawarma Falafel',
#  863: 'Cafe Esplanade',
#  864: 'Chili Hot Pot',
#  865: "Renegade's Pub",
#  866: 'Chacarero',
#  867: 'Merrill & Co.',
#  868: 'Oisa Ramen',
#  869: "Luke's Lobster Downtown Crossing",
#  870: '29 Newbury Street Restaurant',
#  871: 'Nud Pob Thai Cuisine',
#  872: 'Pret a Manger',
#  873: '24 Hour Pizza Delivery',
#  874: 'Oath Pizza - Boston',
#  875: 'Asian Garden',
#  876: "Maria's Kitchen",
#  877: 'Bel Ari',
#  878: 'The Oyster Bar',
#  879: 'Cafe Hemshin',
#  880: 'Anchovies',
#  881: 'Roka',
#  882: 'China Gourmet Restaurant',
#  883: 'Basho Japanese Brasserie',
#  884: 'Andalé',
#  885: 'Gourmet Garden',
#  886: 'Brownstone',
#  887: 'Bon Appetit Creperie',
#  888: 'Delux Café',
#  889: "Green Leaf's Grille",
#  890: "Lefty's Silver Cart",
#  891: 'Seaport Elite Private Yachts',
#  892: 'Legal Test Kitchen',
#  893: 'The Other Side Cafe',
#  894: 'Ki Bistro',
#  895: "Polcari's Coffee",
#  896: 'Daily Grill',
#  897: 'Ueno Sushi',
#  898: 'Boston Ramen Noodle',
#  899: 'The Social Register',
#  900: 'Top of the Hub',
#  901: 'Rosso B Italian Caffe',
#  902: "Anthony's Pier 4 Restaurant",
#  903: 'Tasty Pot',
#  904: 'Radius Restaurant',
#  905: 'Quic Pic BBQ',
#  906: 'Mooo Restaurant',
#  907: 'Gourmet India',
#  908: "G'vanni's",
#  909: 'Dot 2 Dot Café',
#  910: 'Faneuil Hall Marketplace',
#  911: 'Pita Thyme',
#  912: 'Au Chocolat',
#  913: 'Blackthorn Bar',
#  914: '711 Bistro & Sushi Bar',
#  915: 'Wai Style Restaurant',
#  916: 'BBQ Chicken Allston',
#  917: 'Lollicup',
#  918: "Emma's",
#  919: 'Ashburton Cafe',
#  920: 'Dumpling Cafe',
#  921: 'FoMu Ice Cream',
#  922: 'Boston Billiard Club',
#  923: 'BenCotto',
#  924: 'Brighton Best Pizza',
#  925: 'Dumpling King',
#  926: "Lu's Sandwich Shop",
#  927: 'Noodles King',
#  928: 'Hot Tomatoes Express',
#  929: 'Tradesman Coffee Shop & Lounge',
#  930: 'Caffe Nero',
#  931: 'Grill 23 & Bar',
#  932: 'Victoria Seafood Restaurant',
#  933: 'Love Art Sushi',
#  934: 'Papagayo Downtown',
#  935: 'Bailey & Sage',
#  936: "Murphy's Law",
#  937: 'Caffé Vittoria',
#  938: 'Doña Habana',
#  939: 'Troquet on South',
#  940: 'Zoup!',
#  941: 'Cheeky Monkey Brewing',
#  942: "Fenway Johnnie's",
#  943: 'Savvor Restaurant and Lounge',
#  944: 'Capital One Café',
#  945: 'Food For The Soul',
#  946: '4th Wall Restaurant & Bar',
#  947: 'Revelry Food Truck',
#  948: 'BarLola Tapas Lounge',
#  949: "Al Capone's V",
#  950: 'Blazing Paddles',
#  951: 'KO Pies At the Shipyard',
#  952: 'R & S Jamaican Restaurant',
#  953: 'Pollos A La Brasa El Chalan',
#  954: 'TaQueria Mexican Grill',
#  955: 'Troquet',
#  956: 'Channel Café',
#  957: 'Popeyes Louisiana Kitchen',
#  958: 'Blue Glass Cafe',
#  959: 'Café Susu by Suitsupply',
#  960: "McGreevy's",
#  961: 'Roly Poly',
#  962: 'Corner Tavern',
#  963: 'Saladworks',
#  964: 'Banq',
#  965: 'Blackstone Grill',
#  966: '465 Bar and Restaurant',
#  967: 'Viga',
#  968: 'Prestige Cuisine',
#  969: 'City Table',
#  970: "Sweet 'n Nasty",
#  971: "Spike's Junkyard Dogs",
#  972: 'Sergios Pizzaria',
#  973: 'Figs by Todd English',
#  974: 'Bella Vista',
#  975: 'Boston Doghouse',
#  976: 'Sunny Cafe',
#  977: 'Grille Zone',
#  978: 'Casserole Cafe',
#  979: 'Stuart Street Grill',
#  980: 'Lincoln Bar & Grill',
#  981: 'Soul Fire BBQ',
#  982: 'Sakura Japan',
#  983: '75 on Liberty Wharf',
#  984: 'Great Chef',
#  985: 'Flour Bakery + Café',
#  986: 'Yada Yada',
#  987: "Lulu's Bake Shoppe",
#  988: "Billy's Sub Shop",
#  989: 'Table',
#  990: 'Burritos Express',
#  991: 'Sweet Tomatoes Pizza Truck',
#  992: 'Il Giardino Cafe',
#  993: 'Chefstro',
#  994: "Pauli's",
#  995: 'The Dining Car',
#  996: 'Lithuanian Kitchen',
#  997: 'Logan Airport Gulf',
#  998: 'Red Island Restaurant',
#  999: 'Saigon Fusion',
#  ...}

# %%
restaurant_to_index = {v: i for i, v in index_to_restaurant.items()}

# %%
tfidf_vec = TfidfVectorizer(stop_words = 'english')

# %%
word_splitter = re.compile(r"""
    (\w+)
    """, re.VERBOSE)

def getwords(sent):
    return [w.lower() 
            for w in word_splitter.findall(sent)]

# %%
stemmer=PorterStemmer()
reviews = []
counter = 0
review_idx_for_restaurant = dict()
for restaurant, restaurant_dic in small_data.items():
    indices = []
    for review in restaurant_dic['reviews']:
        all_words = getwords(review['text'])
        stem_text = [stemmer.stem(t.lower()) for t in all_words]
        reviews.append(" ".join(stem_text))
        indices.append(counter)
        counter += 1
    review_idx_for_restaurant[restaurant] = indices

# %%
tfidf_mat = tfidf_vec.fit_transform(reviews).toarray()

# %%
def build_movie_sims_cos(num_movies, input_doc_mat):
    """Returns a matrix of size num_movies x num_movies where for (i,j), entry [i,j]
       should be the cosine similarity between the movie with index i and the movie with index j
        
    Note: All movies are trivially perfectly similar to themselves, so the diagonals of the output matrix should be 1.
    
    Params: {num_movies: Integer,
             input_doc_mat: Numpy Array,
             movie_index_to_name: Dict,
             movie_name_to_index: Dict,
             input_get_sim_method: Function}
    Returns: Numpy Array 
    """
    cos_sim = np.zeros((num_movies, num_movies))
    norms = np.linalg.norm(input_doc_mat, axis=1)
    for i in range(num_movies):
        for j in range(num_movies):
            cos_sim[i][j] = np.dot(input_doc_mat[i], input_doc_mat[j])/(norms[i] * norms[j])
    return cos_sim

# %%
sims_cos = build_movie_sims_cos(len(reviews), tfidf_mat)
# Out:
# C:\Users\sahar\Cornell\CS4300\cs4300-projectenv\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars

# %%
review_splitter = [ids[0] for ids in review_idx_for_restaurant.values()][1:]

# %%
def get_ranked_restaurants(in_restaurant, sim_matrix):
    # input restaurant will have 11 reviews
    # find every row that corresponds to a review for input restaurant
    # take the average of them
    # group by every 10
    rest_idx = restaurant_to_index[in_restaurant]
    review_ids = review_idx_for_restaurant[in_restaurant]
    review_sims = sim_matrix[review_ids]
    review_sims = np.mean(review_sims, axis=0)
    restaurant_sims = [np.mean(arr) for arr in np.split(review_sims, review_splitter)]
    rest_lst = [(index_to_restaurant[i], s) for i,s in enumerate(restaurant_sims)]
    rest_lst = rest_lst[:rest_idx] + rest_lst[rest_idx+1:]
    rest_lst = sorted(rest_lst, key=lambda x: -x[1])
    return rest_lst

# %%
test = "Longwood Galleria"
top_restaurants = get_ranked_restaurants(test, sims_cos)

# %%
for rev in small_data[test]['reviews'][:3]:
    print(rev['text'])
    print("///////")
# Out:
# Seeing more variety for food in the North Shore has me pumped! There is a Poké place in Beverly, but it's a little far. However, this is down the street for me. Not so excited that it is physically located in the mall, but it makes sense. Well, at the time before the whole Corona Virus pandemic started. Lame.
#
# I also enjoy that this is a small company from Maine opening up here. Similar to Hop & Grind, the restaurant is run by the owner's and from what I understand is similar to a restaurant in New Hampshire as well.
#
# The food, we must talk about the food darling. The food is fresh and lighter fare. I always feel a little unsatisfied with the bowls, which the Teriyaki Musubi helped put in a dent. But it's healthy and doesn't leave one feeling run down. There are so many cheeseburgers you can hammer down before you're saying "damn I need a salad or something." This is a great option. It is fast; prepped and the bowl is put together right in front of you. It's a healthier option with regards to fast food, and I hope people are willing to give this place a shot.
# ///////
# i was heading to singing beach from boston, started to get the munchies, and craved for a salad.  I found big fin pokie and after realizing it's in a mall, I seriously hesitated.  But my craving over powered my "ugh" moment for going into a mall.  I parked near the food court entrance, big fin is in the way back on the left adjacent to Claire's (where you get yo sparkles on).
#
# I didn't think much of the set up, basically a chipotle styled service.  I ordered the spicy tuna on a bed of salad instead of rice.  When the person making my salad, I noticed the freshness from the glass.  I got excited.  I got my ordered and dug into it.
#
# The spicy tuna was super fresh, the melody of flavors used blended well together, and everything was balanced.  I was shocked.  Am I at a mall eating a pokie ball that is legit on point?  Yes.  The mixed greens, edamame, side of imitation crab salad on top of the salad, and cucumbers were very fresh.  There was some guac/avocado that was a tinge brown but nothing that wasn't inconsumable.
#
# I definitely will be making a pit stop back to this place to and from the beaches.
# ///////
# Stopped by here on a lunch break and I'm glad I finally tried this new option. I didn't realize they had samples, but I'm happy with my picks: salmon and yellow tail (step 1), Kailani and shoyu sauces (step 2), all the mix-ins. Warning: the wasabi and jalapeno combo got a little spicy (though delicious to contrast with the shoyu and are easy to exclude).
#
# For the uninitiated, poké (like Pokémon) is a quick and healthy option that originated in Hawaii. Think Chipotle but with sushi; salad instead of beans but rice is still an option). Freshness is key, and in the west coast this is commonly available and relatively cheap. Unfortunately the east coast has been a lot slower to pick up this trend, and after opening the prices are higher. Big Fin Poke is competing with the rest of the food court though, so the pricing seems to be a great deal. Definitely try it out!
# ///////

# %%
for restaurant in top_restaurants[:3]:
    name = restaurant[0]
    print("RESTAURANT: ", name)
    for rev in small_data[name]['reviews'][:3]:
        print(rev['text'])
        print("///////")
    print("")
# Out:
# RESTAURANT:  Thai Grille
# It's not thai food but i dont care because I hate UMI chicken teriyaki. I really like it and the price isnt bad but could be better.
# ///////
# Good place to grab a quick bite in the mall. I ordered the beef with noodles and it was a huge portion. I ate a third of it and saved the rest for later. The fresh sautéed veggies were good and FHS beef was tender. I would come here again if I find myself shopping there in the future.
# ///////
# I always get the noodles and terriyaki chicken. Its great and the price is right. The staff is young, energetic and does a great job.
# ///////
#
# RESTAURANT:  The NexMex Thing
# Apparently, they are moving to a new location next week!  It'll be "right across the street" although I don't know what the new address is, exactly. We are huge fans and will brave the rush hour traffic to head up here. It's not big so definitely don't be bringing 20 people all at once....although I can't vouch for the new location moving forward.
#
# Taco Tuesdays are a big draw for us, I think they are only $1-2 a piece, just not steak and fish.  But they don't skimp and still come loaded with pico de gallo, guac and other veggies.  The shells aren't your typical corn you'd buy in the grocery store, they are very thick and hold up well when biting.  We also love the elote, caution.....it is SPICAY!!  Smothered in mayo and cayenne pepper although I don't think there is any of the typical cotija cheese.
#
# We were there recently, granted it was like 15 degrees outside but the restaurant was super cold and we had to keep our jackets on the entire time, that wasn't exactly fun.  They also rarely have any horchata in their machine, I don't know if they run out and just don't replenish it or if it's not working.  When I've ordered it, it has been super delicious.
#
# This is really a 4.5 star review because of some of the issues listed above that are minimal but bumped up to a full 5 stars because of how amazing the food has been.  I see people complaining that delivery was "soggy".  Just like a delivered pizza can be cold, that is bound to happen and in no way the restaurants fault.
#
# Stick with the tacos here and you can't go wrong.
# ///////
# I give this a three as it stands but it has a lot of potential!
#
# I came in for lunch because I heard this was a new place and everyone was giving this place 5 star reviews. When you walk in the inside feels a lot bigger than you'd think from just walking by. Everything inside was clean, new and nicely decorated. Although I appreciate the high tops, it was majority high top tables and only 1 normal table, which threw me off a bit.
#
# Now, the reason i give this only 3 stars is the food. I ordered a quesadilla and my bf ordered a burrito. The prices are good and the portions they give are pretty big, but the food overall was bland. I grabbed a pork quesadilla with everything it came with minus the pico-de-gallo. The pork inside were big pieces, a bit chewy, and not much flavor. I wish the pork was shredded, making for more even bites. I think it was the rice that didn't have much flavor, because although it had sour cream, lettuce, beans and cheese, it all just tasted like 1 note. My bfs burrito was a bit better but he doused his in a lot of hot sauce to bring out more flavor.
#
# The gave us some chips and salsa to wait for our food, which was nice, but the salsa tasted like 80% tomato. Maybe try to find something that has more spice? Overall I think they have a lot of potential, but right now as it stands, its overall kinda bland. I know they are new so I have hope, but when I think of Mexican food I think spices, flavor, and that Mexican flare. This didn't not deliver.
# ///////
# Service was nice and fast, without feeling rushed. Options were great. You're not overwhelmed by the menu, but are satisfied with your choices. Decor is just what downtown peabody needs. Peabody is lacking a lot of places for young adults to go to. But you will definitely see me back here. Too bad they don't have their liquor license. Maybe in the future ;) The food was perfect. Though, they were out of fish when we got there. Which in my opinion, if a place 86's a menu item that day, it means everything is made fresh daily, and produce is brought in daily. Which I'm assuming is the case here.
# Burrito was great, I had steak and the boyfriend had pork. Tender and delicious. It was taco Tuesday. 50% off chicken or pork tacos. But they are kinda small and we were starving. Overall great place, great food, great atmosphere. Right down to those super freaking cute cactus candles on the tables.
# Peabody needs more places like this.
# ///////
#
# RESTAURANT:  K Restaurant
# The high star ratings here definitely fooled me. Unfortunately, my experience just fell a bit short.
#
# Let's start with the concept.....
#
# First, walk in and pick up a menu at the counter,
# Proceed to seat yourself at an available table,
# Look over the menu then place your order at the counter,
# Your dishes will be brought to your table once ready,
# When finished with your meal, leave the table as is, they will clear it for you, and you pay at the counter.
#
# Food...
#
# I opted for the Spicy Squid Bibimbap and BBQ Beef Bulgogi. Both dishes were decent. The rice was crisp very well in the hot stone pot. The squid was not as spicy as I hoped it to be. The miso soup that accompanied the dish was nothing to it. Basically lukewarm broth. The beef bulgogi was well marinated and pretty tender. It's also served with small cup of rice. Not an adequate amount considering how large the portion is. And extra charge for more.
#
# Overall...
#
# Everything was overpriced, especially for an establishment that doesn't offer a full dining experience. Like $14 for a rice bowl?!?! And a self service station for water and tea?!? Maybe I've spoiled myself to wait service.... I just can't seem to justify these prices...
# ///////
# Great food and reasonable price! One of the best Korean places in MA!
#
# The fried chicken was definitely on the sweeter side (if not overly sweet). Short ribs were great, though too many bones (what else can you expect for short ribs really). And kimchi fried rice was comparably bland, still good nonetheless!
#
# They do have limited parking spots. The inside of the restaurant seemed clean enough. You place your order from the counter first, before seating yourself. Free water/hot tea on the side. Highly recommended this.
# ///////
# Just moved right around the corner from this place and was so excited to see a Korean restaurant so close. My husband and I decided to give it a try at 8:15 pm on a Saturday night and the place was packed. We learned from the friendly man at the order desk that they just opened 2 weeks ago, and were feeling excited and a little overwhelmed by the outpouring of support.
#
# Right off the bat we were told it would be a 45 minute wait. Not for a table, mind you, but rather the food prep. We were eager to try the place so we said that was okay and had a nice chat while we sat and wait. I ordered the la ribs galbee with rice and kimchee. My hubby got the pork ribs with rice and kimchi. Both were delicious, high quality, authentic, and well worth the wait. We felt right at home surrounded by many Korean families eating equally delicious looking food.
#
# The restaurant is not fancy at all, but they have a nice variety of menu items that range from 10-18 bucks. They also have a water cooler and hot tea dispenser, and friendly service. This may become one of my regular spots in the new neighborhood. Just hope they get used to the new business and streamline the food prep process so you get food faster.
# ///////
